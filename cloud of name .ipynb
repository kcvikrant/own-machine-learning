# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = ['Vikrant','Aparna','SUJU','Menaka','aman','astha','tegbahadur','sunita','maya','niranjana','sharwan giri','ayisha','shreedhar',
      'laxmi','ravi','kaalu','laxman','poonam','kashish','aaradhya','baburam','babita','sudhan','uma','subodh','baghwan']
plt.subplots(figsize=(15,15))
wordcloud  =WordCloud(background_color='black',width=1900,height=1200).generate(" ".join(df))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
